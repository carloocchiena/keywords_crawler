# %% [markdown]
# 19/11/2021
# perfetto, ecco la versione funzionante

# %%
import requests as req
from collections import Counter
from bs4 import BeautifulSoup as BS4
import nltk
from nltk.corpus import stopwords
from concurrent.futures import ThreadPoolExecutor, as_completed

nltk.download('stopwords')

# global var
MAX_THREADS = 50
HEADER = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36'}

# cleaner function to remove non-internal urls   
def cleaner(data):
    """Cleans data from external url"""
    for items in data:
        if items[0:len(our_url)] == our_url:
            temp_data.append(items)
    global clean_data
    clean_data = set(temp_data)

# function to crawls the website and search for internal urls
def crawler(url):
    """Scrape given url and search for internal urls

    Args:
        url (string): provide a complete url in the form "https://www.example.com"

    Returns:
        List: all the urls of the website
    """
    global our_url
    our_url = url

    global temp_data
    temp_data = []
    
    global clean_data
    clean_data = []
    
    raw_data = []
    temp = []  
    limit = 1
    count = 0

    source_code = req.get(url, "html.parser", headers=HEADER).content

    soup = BS4(source_code, 'lxml')

    links = soup.findAll("a", href=True)
    
    # append the internal urls to a list, iteratively
    def raw_append(link):
        raw_data.append(str(link.get("href")))

    with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
        futures = [executor.submit(raw_append, link)for link in links] 
        
    for i in raw_data:
        try:
            if i[0] == "/":
                raw_data.append(url+i)
        except Exception as e:
            print(f"[!!!] Exception occurred (a): {e}")
    
    # call the cleaner function to purge the external urls        
    cleaner(raw_data)
    
    # define a scraper function to run within the multithread executor
    def scraper(link):
        source_code = req.get(link, "html.parser").content
        soup = BS4(source_code, 'lxml')
        bites = soup.findAll("a", href=True)

    while count < limit:    
        try:
            with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
                futures = [executor.submit(scraper, link)for link in clean_data]
                for result in as_completed(futures):
                    temp.append(result.get("href"))
        except Exception as e:
            print(f"[!!!] Exception occurred (b): {e}")      

        cleaner(temp)
        
        # increase the counter, to stay within the limit and avoid very long running loops
        count += 1
         
    return clean_data

# lets' count the number of times a word appears in a given text within each url
def kw_ranking (url):
    """Function to scan the text of each url and count the number of times a word appears

    Args:
        url (string): provide a complete url in the form "https://www.example.com"

    Returns:
        dict: link and kword count
    """    
    # define our list of stopwords
    custom = ["!","'","£","$","%","&","(",")","?","^","*","+","/","-", "©"]  # add further words to be excluded
    stopwords_overall = stopwords.words('italian')  + stopwords.words('english') + custom
    
    # scrape the url
    best = []
           
    page  = req.get(url, "html.parser", headers=HEADER).content

    soup = BS4(page, "lxml")

    text = soup.findAll("p")

    text_clean =[]
    
    # clean the text from unwanted characters
    for slots in text:
        text_clean.append(slots.get_text().lower())

    text_all = "".join(text_clean).replace(",", "").replace(".","").replace("!","").replace("?","").split()

    for word in reversed(text_all):
        if word in stopwords_overall:
            text_all.remove(word)

    rank = Counter(text_all)

    best.append(rank.most_common(5))
    
    named_kw = dict(zip(url, best))
    
    return named_kw
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
url = "https://www.alpiq.com"
links = crawler(url)
links
# Out:
# [!!!] Exception occurred (b): 'Future' object has no attribute 'get'
# {'https://www.alpiq.com/',
#  'https://www.alpiq.com/alpiq-group/about-alpiq',
#  'https://www.alpiq.com/alpiq-group/about-alpiq/ethics-compliance',
#  'https://www.alpiq.com/alpiq-group/about-alpiq/general-terms-and-conditions',
#  'https://www.alpiq.com/alpiq-group/about-alpiq/group-companies',
#  'https://www.alpiq.com/alpiq-group/about-alpiq/publications',
#  'https://www.alpiq.com/alpiq-group/about-alpiq/sustainability',
#  'https://www.alpiq.com/alpiq-group/investor-relations',
#  'https://www.alpiq.com/alpiq-group/investor-relations/ad-hoc-news',
#  'https://www.alpiq.com/alpiq-group/investor-relations/ad-hoc-news/ad-hoc-news-detail/alpiq-wins-first-instance-in-tax-dispute-with-romanian-tax-authority',
#  'https://www.alpiq.com/alpiq-group/investor-relations/ad-hoc-news/ad-hoc-news-detail/johannes-teyssen-nominated-as-new-board-member',
#  'https://www.alpiq.com/alpiq-group/media-relations',
#  'https://www.alpiq.com/alpiq-group/media-relations/media-releases',
#  'https://www.alpiq.com/alpiq-group/media-relations/media-releases/media-release-detail/huescherabach-a-state-of-the-art-small-hydropower-plant-in-harmony-with-the-energy-strategy-and-the-environment',
#  'https://www.alpiq.com/alpiq-group/media-relations/media-releases/media-release-detail/prixalpiq-distinguishes-two-sustainable-water-management-projects',
#  'https://www.alpiq.com/alpiq-group/media-relations/news-stories',
#  'https://www.alpiq.com/alpiq-group/media-relations/news-stories/news-stories-detail/csepel-celebrates-20-1-years-of-operation',
#  'https://www.alpiq.com/alpiq-group/media-relations/news-stories/news-stories-detail/new-steam-turbine-for-novel',
#  'https://www.alpiq.com/career-1/your-future-at-alpiq',
#  'https://www.alpiq.com/career-1/your-future-at-alpiq/#c2105',
#  'https://www.alpiq.com/cookie-notice',
#  'https://www.alpiq.com/copyright',
#  'https://www.alpiq.com/energy-solutions/asset-management',
#  'https://www.alpiq.com/energy-solutions/asset-management/asset-management-for-renewable-energy',
#  'https://www.alpiq.com/energy-solutions/asset-management/asset-management-services',
#  'https://www.alpiq.com/energy-solutions/asset-management/maintenance',
#  'https://www.alpiq.com/energy-solutions/asset-management/operation-and-maintenance',
#  'https://www.alpiq.com/energy-solutions/asset-management/project-management',
#  'https://www.alpiq.com/energy-solutions/asset-management/quality-management',
#  'https://www.alpiq.com/energy-solutions/digital-energy-solutions',
#  'https://www.alpiq.com/energy-solutions/digital-energy-solutions/distributed-ledger-technologies-dlt',
#  'https://www.alpiq.com/energy-solutions/digital-energy-solutions/quinn-energy-management-software',
#  'https://www.alpiq.com/energy-solutions/digital-energy-solutions/reference-swiss-steel',
#  'https://www.alpiq.com/energy-solutions/digital-energy-solutions/reference-werdhoelzli',
#  'https://www.alpiq.com/energy-solutions/electricity-supply',
#  'https://www.alpiq.com/energy-solutions/energy-management',
#  'https://www.alpiq.com/energy-solutions/energy-management/balance-group-management',
#  'https://www.alpiq.com/energy-solutions/energy-management/demand-side-management',
#  'https://www.alpiq.com/energy-solutions/energy-management/energy-consulting',
#  'https://www.alpiq.com/energy-solutions/energy-management/energyknowhow',
#  'https://www.alpiq.com/energy-solutions/energy-management/flexibility-management',
#  'https://www.alpiq.com/energy-solutions/energy-management/power-plant-optimisation',
#  'https://www.alpiq.com/energy-solutions/energy-management/risk-and-portfolio-management',
#  'https://www.alpiq.com/energy-solutions/energy-management/storage-optimisation',
#  'https://www.alpiq.com/energy-solutions/energy-management/zevplus',
#  'https://www.alpiq.com/energy-solutions/gas-supply',
#  'https://www.alpiq.com/energy-solutions/incentive-programme-optimo-plus',
#  'https://www.alpiq.com/energy-solutions/renewable-energy-management',
#  'https://www.alpiq.com/energy-solutions/renewable-energy-management/renewable-energy-management-services',
#  'https://www.alpiq.com/energy-trading/trading-origination',
#  'https://www.alpiq.com/energy-trading/trading-origination/derivatives',
#  'https://www.alpiq.com/energy-trading/trading-origination/electricity-trading',
#  'https://www.alpiq.com/energy-trading/trading-origination/energy-certificates',
#  'https://www.alpiq.com/energy-trading/trading-origination/gas-trading',
#  'https://www.alpiq.com/energy-trading/trading-origination/market-access',
#  'https://www.alpiq.com/legal-information',
#  'https://www.alpiq.com/power-generation/hydrogen-production',
#  'https://www.alpiq.com/power-generation/hydropower-plants',
#  'https://www.alpiq.com/power-generation/hydropower-plants/prixalpiq',
#  'https://www.alpiq.com/power-generation/hydropower-plants/projects',
#  'https://www.alpiq.com/power-generation/hydropower-plants/run-of-river-power-plants',
#  'https://www.alpiq.com/power-generation/hydropower-plants/storage-power-plants',
#  'https://www.alpiq.com/power-generation/new-renewable-energy-sources',
#  'https://www.alpiq.com/power-generation/new-renewable-energy-sources/#c5873',
#  'https://www.alpiq.com/power-generation/new-renewable-energy-sources/#c5914',
#  'https://www.alpiq.com/power-generation/new-renewable-energy-sources/projects',
#  'https://www.alpiq.com/power-generation/new-renewable-energy-sources/small-scale-hydropower-plants',
#  'https://www.alpiq.com/power-generation/quality-management',
#  'https://www.alpiq.com/power-generation/quality-management/our-quality-labels',
#  'https://www.alpiq.com/power-generation/reference-fmhl',
#  'https://www.alpiq.com/power-generation/thermal-power-plants',
#  'https://www.alpiq.com/power-generation/thermal-power-plants/#c12025',
#  'https://www.alpiq.com/power-generation/thermal-power-plants/#c6687',
#  'https://www.alpiq.com/power-generation/thermal-power-plants/nuclear-power/goesgen',
#  'https://www.alpiq.com/power-generation/visit-our-power-plants',
#  'https://www.alpiq.com/power-generation/visit-our-power-plants/register-for-a-power-plant-tour',
#  'https://www.alpiq.com/privacy',
#  'https://www.alpiq.com/remit-information',
#  'https://www.alpiq.com/sitemap'}

# %%
with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
    futures = {executor.submit(kw_ranking, link): link for link in links}
    for result in as_completed(futures):
        link = futures.get(result)
        try:
            data=result.result()
        except Exception as e:
            print(f"[!!!] Exception occurred (b): {e}") 
        else:
            print (f"Link: {link}:\nData:{data}")
# Out:
# Link: https://www.alpiq.com/alpiq-group/about-alpiq:
# Data:{'h': [('energy', 4), ('power', 4), ('alpiq', 4), ('information', 4), ('see', 3)]}
# Link: https://www.alpiq.com/energy-solutions/asset-management/asset-management-for-renewable-energy:
# Data:{'h': [('plants', 7), ('performance', 4), ('power', 4), ('see', 3), ('production', 3)]}
# Link: https://www.alpiq.com/alpiq-group/media-relations/media-releases:
# Data:{'h': [('alpiq', 6), ('–', 5), ('2021', 3), ('holding', 3), ('21', 3)]}
# Link: https://www.alpiq.com/power-generation/thermal-power-plants/#c12025:
# Data:{'h': [('power', 14), ('plants', 11), ('electricity', 9), ('learn', 7), ('switzerland', 5)]}
# Link: https://www.alpiq.com/remit-information:
# Data:{'h': [('country', 2), ('see', 2), ('content', 2), ('products', 2), ('locationcountry', 2)]}
# Link: https://www.alpiq.com/energy-solutions/digital-energy-solutions/reference-swiss-steel:
# Data:{'h': [('energy', 19), ('consumption', 9), ('prediction', 7), ('costs', 6), ('balance', 6)]}
# Link: https://www.alpiq.com/:
# Data:{'h': [('energy', 16), ('power', 12), ('alpiq', 9), ('plant', 7), ('new', 6)]}
# Link: https://www.alpiq.com/alpiq-group/about-alpiq/sustainability:
# Data:{'h': [('alpiq', 3), ('employees', 3), ('social', 3), ('country', 2), ('see', 2)]}
# Link: https://www.alpiq.com/alpiq-group/about-alpiq/ethics-compliance:
# Data:{'h': [('alpiq', 6), ('employees', 3), ('compliance', 3), ('report', 3), ('country', 2)]}
# Link: https://www.alpiq.com/alpiq-group/about-alpiq/general-terms-and-conditions:
# Data:{'h': [('country', 2), ('see', 2), ('content', 2), ('products', 2), ('locationcountry', 2)]}
# Link: https://www.alpiq.com/power-generation/new-renewable-energy-sources/#c5873:
# Data:{'h': [('wind', 18), ('technical', 11), ('power', 10), ('details', 10), ('energy', 9)]}
# Link: https://www.alpiq.com/power-generation/new-renewable-energy-sources/#c5914:
# Data:{'h': [('wind', 18), ('technical', 11), ('power', 10), ('details', 10), ('energy', 9)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/zevplus:
# Data:{'h': [('energy', 11), ('consumption', 10), ('electricity', 9), ('grid', 6), ('systems', 5)]}
# Link: https://www.alpiq.com/alpiq-group/investor-relations/ad-hoc-news:
# Data:{'h': [('alpiq', 7), ('–', 6), ('2021', 4), ('country', 2), ('see', 2)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/power-plant-optimisation:
# Data:{'h': [('power', 9), ('energy', 6), ('plant', 5), ('optimisation', 4), ('develop', 3)]}
# Link: https://www.alpiq.com/privacy:
# Data:{'h': [('data', 98), ('personal', 75), ('controller', 34), ('processing', 30), ('interests', 24)]}
# HTTPSConnectionPool(host='entreprises.alpiq.fr', port=443): Max retries exceeded with url: /mentions-legales (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)')))
# Link: https://www.alpiq.com/energy-solutions/asset-management/project-management:
# Data:{'h': [('power', 9), ('plants', 9), ('project', 6), ('plant', 5), ('de', 4)]}
# Link: https://www.alpiq.com/power-generation/hydropower-plants/run-of-river-power-plants:
# Data:{'h': [('power', 9), ('run-of-river', 5), ('plant', 5), ('swiss', 5), ('canton', 4)]}
# Link: https://www.alpiq.com/power-generation/new-renewable-energy-sources/small-scale-hydropower-plants:
# Data:{'h': [('technical', 30), ('details', 30), ('plant', 28), ('swiss', 27), ('canton', 27)]}
# Link: https://www.alpiq.com/power-generation/hydropower-plants:
# Data:{'h': [('plants', 8), ('power', 7), ('hydropower', 4), ('–', 4), ('alpiq', 4)]}
# Link: https://www.alpiq.com/energy-solutions/gas-supply:
# Data:{'h': [('products', 7), ('gas', 4), ('european', 3), ('offers', 3), ('individual', 3)]}
# Link: https://www.alpiq.com/sitemap:
# Data:{'h': [('country', 2), ('see', 2), ('content', 2), ('products', 2), ('locationcountry', 2)]}
# Link: https://www.alpiq.com/power-generation/thermal-power-plants/#c6687:
# Data:{'h': [('power', 14), ('plants', 11), ('electricity', 9), ('learn', 7), ('switzerland', 5)]}
# Link: https://www.alpiq.com/alpiq-group/media-relations/news-stories/news-stories-detail/csepel-celebrates-20-1-years-of-operation:
# Data:{'h': [('csepel', 6), ('power', 6), ('plant', 5), ('years', 4), ('safety', 4)]}
# Link: https://www.alpiq.com/energy-trading/trading-origination/derivatives:
# Data:{'h': [('products', 5), ('gas', 4), ('trading', 3), ('offer', 3), ('options', 3)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/demand-side-management:
# Data:{'h': [('energy', 7), ('products', 4), ('optimisation', 4), ('power', 3), ('system', 3)]}
# Link: https://www.alpiq.com/power-generation/new-renewable-energy-sources/projects:
# Data:{'h': [('wind', 4), ('project', 3), ('country', 2), ('see', 2), ('content', 2)]}
# Link: https://www.alpiq.com/power-generation/reference-fmhl:
# Data:{'h': [('power', 11), ('electricity', 7), ('plant', 6), ('new', 5), ('energy', 5)]}
# Link: https://www.alpiq.com/power-generation/visit-our-power-plants/register-for-a-power-plant-tour:
# Data:{'h': [('emosson', 3), ('country', 2), ('see', 2), ('content', 2), ('products', 2)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/energy-consulting:
# Data:{'h': [('energy', 5), ('market', 4), ('help', 3), ('electricity', 3), ('country', 2)]}
# Link: https://www.alpiq.com/energy-solutions/digital-energy-solutions/distributed-ledger-technologies-dlt:
# Data:{'h': [('electricity', 9), ('energy', 7), ('power', 6), ('dlts', 5), ('storage', 5)]}
# Link: https://www.alpiq.com/alpiq-group/about-alpiq/publications:
# Data:{'h': [('report', 4), ('alpiq', 3), ('holding', 3), ('country', 2), ('see', 2)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management:
# Data:{'h': [('energy', 16), ('alpiq', 10), ('management', 7), ('optimisation', 6), ('power', 4)]}
# Link: https://www.alpiq.com/power-generation/thermal-power-plants/nuclear-power/goesgen:
# Data:{'h': [('power', 4), ('plant', 4), ('country', 2), ('see', 2), ('content', 2)]}
# Link: https://www.alpiq.com/power-generation/hydrogen-production:
# Data:{'h': [('hydrogen', 18), ('energy', 14), ('power', 8), ('production', 7), ('hydrospider', 6)]}
# Link: https://www.alpiq.com/energy-trading/trading-origination/market-access:
# Data:{'h': [('market', 5), ('products', 4), ('portfolio', 4), ('find', 4), ('gas', 3)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/storage-optimisation:
# Data:{'h': [('storage', 4), ('optimisation', 4), ('battery', 3), ('energy', 3), ('country', 2)]}
# Link: https://www.alpiq.com/alpiq-group/about-alpiq/group-companies:
# Data:{'h': [('energy', 106), ('alpiq', 76), ('electricity', 35), ('power', 29), ('trading', 27)]}
# Link: https://www.alpiq.com/energy-solutions/asset-management/asset-management-services:
# Data:{'h': [('power', 13), ('management', 11), ('plants', 9), ('asset', 7), ('sa', 7)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/balance-group-management:
# Data:{'h': [('balance', 9), ('energy', 7), ('group', 6), ('groups', 4), ('balancing', 4)]}
# Link: https://www.alpiq.com/power-generation/new-renewable-energy-sources:
# Data:{'h': [('wind', 18), ('technical', 11), ('power', 10), ('details', 10), ('energy', 9)]}
# Link: https://www.alpiq.com/energy-solutions/digital-energy-solutions/quinn-energy-management-software:
# Data:{'h': [('energy', 13), ('management', 6), ('digital', 3), ('alpiq', 3), ('software', 3)]}
# Link: https://www.alpiq.com/energy-solutions/electricity-supply:
# Data:{'h': [('electricity', 11), ('products', 8), ('price', 6), ('supply', 5), ('alpiq', 5)]}
# Link: https://www.alpiq.com/energy-solutions/incentive-programme-optimo-plus:
# Data:{'h': [('efficiency', 8), ('kwh', 8), ('implementation', 7), ('swiss', 7), ('yearinvestment', 7)]}
# Link: https://www.alpiq.com/energy-solutions/digital-energy-solutions:
# Data:{'h': [('energy', 19), ('management', 6), ('digital', 5), ('platform', 4), ('alpiq', 4)]}
# Link: https://www.alpiq.com/energy-trading/trading-origination/electricity-trading:
# Data:{'h': [('products', 4), ('portfolio', 4), ('electricity', 4), ('gas', 4), ('find', 3)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/risk-and-portfolio-management:
# Data:{'h': [('portfolio', 5), ('market', 5), ('energy', 5), ('products', 4), ('risk', 3)]}
# Link: https://www.alpiq.com/energy-solutions/asset-management/quality-management:
# Data:{'h': [('power', 12), ('iso', 8), ('plants', 7), ('quality', 6), ('001', 5)]}
# Link: https://www.alpiq.com/power-generation/quality-management:
# Data:{'h': [('power', 11), ('plants', 6), ('certified', 6), ('quality', 6), ('iso', 5)]}
# Link: https://www.alpiq.com/energy-trading/trading-origination/gas-trading:
# Data:{'h': [('products', 4), ('portfolio', 4), ('find', 3), ('country', 2), ('see', 2)]}
# Link: https://www.alpiq.com/copyright:
# Data:{'h': [('website', 4), ('content', 3), ('country', 2), ('see', 2), ('products', 2)]}
# Link: https://www.alpiq.com/power-generation/hydropower-plants/storage-power-plants:
# Data:{'h': [('power', 11), ('swiss', 11), ('canton', 11), ('plant', 10), ('valaislearn', 7)]}
# Link: https://www.alpiq.com/energy-solutions/digital-energy-solutions/reference-werdhoelzli:
# Data:{'h': [('energy', 9), ('power', 6), ('added', 6), ('value', 6), ('new', 4)]}
# Link: https://www.alpiq.com/alpiq-group/media-relations:
# Data:{'h': [('–', 4), ('alpiq', 4), ('plant', 4), ('power', 4), ('+41', 4)]}
# Link: https://www.alpiq.com/alpiq-group/investor-relations:
# Data:{'h': [('alpiq', 4), ('–', 3), ('+41', 3), ('country', 2), ('see', 2)]}
# Link: https://www.alpiq.com/power-generation/visit-our-power-plants:
# Data:{'h': [('guided', 9), ('pdf', 8), ('dam', 7), ('power', 6), ('landscape', 6)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/flexibility-management:
# Data:{'h': [('flexibility', 4), ('consumption', 4), ('management', 3), ('capacity', 3), ('power', 3)]}
# Link: https://www.alpiq.com/energy-trading/trading-origination:
# Data:{'h': [('trading', 9), ('products', 6), ('portfolio', 6), ('gas', 6), ('energy', 6)]}
# Link: https://www.alpiq.com/career-1/your-future-at-alpiq/#c2105:
# Data:{'h': [('alpiq', 5), ('career', 3), ('country', 2), ('see', 2), ('content', 2)]}
# Link: https://www.alpiq.com/power-generation/hydropower-plants/prixalpiq:
# Data:{'h': [('water', 35), ('project', 20), ('valais', 17), ('–', 11), ('resource', 10)]}
# Link: https://www.alpiq.com/cookie-notice:
# Data:{'h': [('site', 3), ('information', 3), ('cookies', 3), ('choose', 2), ('country', 2)]}
# Link: https://www.alpiq.com/power-generation/thermal-power-plants:
# Data:{'h': [('power', 14), ('plants', 11), ('electricity', 9), ('learn', 7), ('switzerland', 5)]}
# Link: https://www.alpiq.com/energy-solutions/asset-management/maintenance:
# Data:{'h': [('power', 6), ('maintenance', 5), ('plants', 3), ('plant', 3), ('down-time', 3)]}
# Link: https://www.alpiq.com/energy-solutions/asset-management:
# Data:{'h': [('power', 8), ('plants', 6), ('alpiq', 6), ('hydropower', 5), ('plant', 5)]}
# Link: https://www.alpiq.com/energy-trading/trading-origination/energy-certificates:
# Data:{'h': [('certificates', 5), ('products', 4), ('offer', 4), ('find', 3), ('gas', 3)]}
# Link: https://www.alpiq.com/energy-solutions/renewable-energy-management:
# Data:{'h': [('energy', 8), ('services', 8), ('renewable', 6), ('market', 6), ('management', 5)]}
# Link: https://www.alpiq.com/career-1/your-future-at-alpiq:
# Data:{'h': [('alpiq', 5), ('career', 3), ('country', 2), ('see', 2), ('content', 2)]}
# Link: https://www.alpiq.com/power-generation/quality-management/our-quality-labels:
# Data:{'h': [('quality', 3), ('alpiq', 3), ('country', 2), ('see', 2), ('content', 2)]}
# Link: https://www.alpiq.com/alpiq-group/media-relations/news-stories:
# Data:{'h': [('power', 5), ('plant', 4), ('energy', 4), ('alpiq', 3), ('country', 2)]}
# Link: https://www.alpiq.com/energy-solutions/asset-management/operation-and-maintenance:
# Data:{'h': [('plants', 7), ('power', 5), ('monitoring', 4), ('wind', 4), ('hydropower', 4)]}
# Link: https://www.alpiq.com/power-generation/hydropower-plants/projects:
# Data:{'h': [('de', 3), ('country', 2), ('see', 2), ('content', 2), ('products', 2)]}
# Link: https://www.alpiq.com/energy-solutions/renewable-energy-management/renewable-energy-management-services:
# Data:{'h': [('market', 7), ('power', 6), ('production', 5), ('energy', 4), ('marketing', 4)]}
# Link: https://www.alpiq.com/alpiq-group/media-relations/news-stories/news-stories-detail/new-steam-turbine-for-novel:
# Data:{'h': [('plant', 8), ('alpiq', 7), ('steam', 5), ('turbine', 5), ('radici', 5)]}
# Link: https://www.alpiq.com/energy-solutions/energy-management/energyknowhow:
# Data:{'h': [('energy', 22), ('alpiq', 6), ('see', 4), ('risk', 4), ('need', 4)]}
# Link: https://www.alpiq.com/alpiq-group/investor-relations/ad-hoc-news/ad-hoc-news-detail/alpiq-wins-first-instance-in-tax-dispute-with-romanian-tax-authority:
# Data:{'h': [('tax', 3), ('alpiq', 3), ('dated', 3), ('+41', 3), ('country', 2)]}
# Link: https://www.alpiq.com/alpiq-group/media-relations/media-releases/media-release-detail/huescherabach-a-state-of-the-art-small-hydropower-plant-in-harmony-with-the-energy-strategy-and-the-environment:
# Data:{'h': [('plant', 11), ('energy', 7), ('municipality', 7), ('hydropower', 6), ('renewable', 5)]}
# Link: https://www.alpiq.com/alpiq-group/investor-relations/ad-hoc-news/ad-hoc-news-detail/johannes-teyssen-nominated-as-new-board-member:
# Data:{'h': [('alpiq', 10), ('energy', 6), ('european', 6), ('alder', 5), ('company', 5)]}
# Link: https://www.alpiq.com/alpiq-group/media-relations/media-releases/media-release-detail/prixalpiq-distinguishes-two-sustainable-water-management-projects:
# Data:{'h': [('water', 20), ('irrigation', 7), ('alpiq', 6), ('#prixalpiq', 6), ('valais', 6)]}
